# %%
def check_engagement(like_values):
    total = 0
    for number in like_values:
        total = total + number
    print("Total Likes:", total)
    if total >= 1000:
        print("Post Status: Viral Post")
    else:
        print("Post Status: Normal Engagement")
likes_data = [120, 340, 210, 180, 200]
check_engagement(likes_data)
# Out:
# Total Likes: 1050
# Post Status: Viral Post

# %%
def monitor_medicine(stock):
    print("Medicine Stock:", stock)
    if stock < 10:
        print("Status: Low Stock Alert")
    else:
        print("Status: Stock Sufficient")
available_units = 6
monitor_medicine(available_units)
# Out:
# Medicine Stock: 6
# Status: Low Stock Alert

# %%
def check_rainfall(season_rain, minimum_required):
    sum_of_rain = 0
    for value in season_rain:
        sum_of_rain += value
    average = sum_of_rain / len(season_rain)
    print("Average Rainfall:", int(average))
    if average >= minimum_required:
        print("Rainfall Status: Adequate Rainfall")
    else:
        print("Rainfall Status: Inadequate Rainfall")
rain_data = [65, 78, 72, 69, 76]
required_level = 70
check_rainfall(rain_data, required_level)
# Out:
# Average Rainfall: 72
# Rainfall Status: Adequate Rainfall

# %%
def check_usernames(usernames):
    seen_names = set()
    has_duplicate = False
    for name in usernames:
        if name in seen_names:
            has_duplicate = True
            break
        seen_names.add(name)
    if has_duplicate:
        print("Duplicate Accounts Found: Yes")
    else:
        print("Duplicate Accounts Found: No")
user_data = ["userA", "userB", "userC", "userA"]
check_usernames(user_data)
# Out:
# Duplicate Accounts Found: Yes

# %%
def verify_appointment(age_value):
    print("Patient Age:", age_value)
    if age_value >= 18:
        print("Eligibility Status: Eligible")
    else:
        print("Eligibility Status: Not Eligible")
age_input = 21
verify_appointment(age_input)
# Out:
# Patient Age: 21
# Eligibility Status: Eligible

# %%
def identify_premium_prices(price_values, limit_value):
    high_value_crops = []
    for price in price_values:
        if price > limit_value:
            high_value_crops.append(price)
    print("Premium Crops:", high_value_crops)
prices = [2100, 1800, 2500, 1999, 3200]
premium_threshold = 2000
identify_premium_prices(prices, premium_threshold)
# Out:
# Premium Crops: [2100, 2500, 3200]

# %%
def check_application_status(error_count):
    print("Error Count:", error_count)
    if error_count == 0:
        status = "Healthy"
    elif error_count <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"
    print("System Status:", status)
errors_detected = 7
check_application_status(errors_detected)
# Out:
# Error Count: 7
# System Status: Critical Issues

# %%
def check_daily_limit(transaction_value):
    maximum_allowed = 50000
    print("Transaction Amount:", transaction_value)
    if transaction_value > maximum_allowed:
        print("Transaction Status: Rejected")
    else:
        print("Transaction Status: Approved")
amount_today = 60000
check_daily_limit(amount_today)
# Out:
# Transaction Amount: 60000
# Transaction Status: Rejected

# %%
def check_exam_eligibility(attendance_data):
    total_sessions = len(attendance_data)
    present_count = 0
    for entry in attendance_data:
        if entry == 1:
            present_count = present_count + 1
    attendance_percent = (present_count / total_sessions) * 100
    print("Attendance Percentage:", attendance_percent)
    if attendance_percent >= 75:
        print("Exam Eligibility: Eligible")
    else:
        print("Exam Eligibility: Not Eligible")
# sample input(1 = Present, 0 = Absent)
record = [1, 1, 0, 1, 1]
check_exam_eligibility(record)
# Out:
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible

# %%
def compute_bill(units):
    total_cost = 0
    if units <= 100:
        total_cost = units * 3
    elif units <= 200:
        first_part = 100 * 3
        remaining_units = units - 100
        total_cost = first_part + (remaining_units * 5)
    else:
        first_part = 100 * 3
        second_part = 100 * 5
        remaining_units = units - 200
        total_cost = first_part + second_part + (remaining_units * 7)
    if total_cost < 500:
        category = "Low Usage"
    elif total_cost <= 1500:
        category = "Moderate Usage"
    else:
        category = "High Usage"
    return total_cost, category
units_used = 250
bill, usage_status = compute_bill(units_used)
print("Units Consumed:", units_used)
print("Total Bill:", bill)
print("Usage Category:", usage_status)
# Out:
# Units Consumed: 250
# Total Bill: 1150
# Usage Category: Moderate Usage
